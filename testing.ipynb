# %%
import json

data = []
with open("/Users/nizarsayad/Documents/VSCode/Jedha_Fullstack/Final-Project/bookcorpus/url_list.jsonl", "r") as f:
    for line in f:
        data.append(json.loads(line))

# %%
data[0]["genres"]
# Out:
# {'page': 'https://www.smashwords.com/books/view/246580',
#  'epub': 'https://www.smashwords.com/books/download/246580/8/latest/0/0/silence.epub',
#  'txt': 'https://www.smashwords.com/books/download/246580/6/latest/0/0/silence.txt',
#  'title': 'Silence',
#  'author': 'Natasha Preston',
#  'genres': ['\n                            Category: Fiction » Romance » New adult ',
#   '\n                            Category: Fiction » Romance » Contemporary '],
#  'publish': 'Oct. 19, 2012',
#  'num_words': 84880,
#  'b_idx': 1}

# %%
# Check the unique genres in the dataset
genres = []
for i in range(len(data)):
    genres.append(data[i]['genres'])

# %%
# Keep genres where there is 'Thriller' in the list
thriller = []
for i in range(len(genres)):
    for text in genres[i]:
        if 'Thriller' or 'Horror' in text:
            thriller.append(data[i])

# %%
thriller
# Out:
# [{'page': 'https://www.smashwords.com/books/view/246580',
#   'epub': 'https://www.smashwords.com/books/download/246580/8/latest/0/0/silence.epub',
#   'txt': 'https://www.smashwords.com/books/download/246580/6/latest/0/0/silence.txt',
#   'title': 'Silence',
#   'author': 'Natasha Preston',
#   'genres': ['\n                            Category: Fiction » Romance » New adult ',
#    '\n                            Category: Fiction » Romance » Contemporary '],
#   'publish': 'Oct. 19, 2012',
#   'num_words': 84880,
#   'b_idx': 1},
#  {'page': 'https://www.smashwords.com/books/view/246580',
#   'epub': 'https://www.smashwords.com/books/download/246580/8/latest/0/0/silence.epub',
#   'txt': 'https://www.smashwords.com/books/download/246580/6/latest/0/0/silence.txt',
#   'title': 'Silence',
#   'author': 'Natasha Preston',
#   'genres': ['\n                            Category: Fiction » Romance » New adult ',
# ...

# %%
# Import CodeHasher
from streamlit.hashing import _CodeHasher
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/nizarsayad/Documents/VSCode/Jedha_Fullstack/Final-Project/testing.ipynb Cell 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/nizarsayad/Documents/VSCode/Jedha_Fullstack/Final-Project/testing.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # Import CodeHasher
# ----> <a href='vscode-notebook-cell:/Users/nizarsayad/Documents/VSCode/Jedha_Fullstack/Final-Project/testing.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> from streamlit.hashing import _CodeHasher
#
# ModuleNotFoundError: No module named 'streamlit.hashing'

# %%
import streamlit as st

# %%
state = st.session_state

# %%
state
# Out:
# 2023-04-13 00:46:48.195 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`

# %%
state.sync()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/session_state.py:370, in SessionState.__getitem__(self, key)
#     369 try:
# --> 370     return self._getitem(widget_id, key)
#     371 except KeyError:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/session_state.py:415, in SessionState._getitem(self, widget_id, user_key)
#     414 # We'll never get here
# --> 415 raise KeyError
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/streamlit/runtime/state/session_state_proxy.py:119, in SessionStateProxy.__getattr__(self, key)
#     118 try:
# --> 119     return self[key]
#     120 except KeyError:
#
# ...

# %%
help(st.selectbox)
# Out:
# Help on method selectbox in module streamlit.delta_generator:
#
# selectbox(label: str, options: Union[Iterable[~T], streamlit.type_util.DataFrameGenericAlias[~T]], index: int = 0, format_func: Callable[[Any], Any] = <class 'str'>, key: Union[str, int, NoneType] = None, help: Optional[str] = None, on_change: Optional[Callable[..., NoneType]] = None, args: Optional[Tuple[Any, ...]] = None, kwargs: Optional[Dict[str, Any]] = None, *, disabled: bool = False, label_visibility: Literal['visible', 'hidden', 'collapsed'] = 'visible') -> Optional[~T] method of streamlit.delta_generator.DeltaGenerator instance
#     Display a select widget.
#
#     Parameters
#     ----------
#     label : str
#         A short label explaining to the user what this select widget is for.
#         The label can optionally contain Markdown and supports the following
#         elements: Bold, Italics, Strikethroughs, Inline Code, Emojis, and Links.
#
#         This also supports:
#
# ...

# %%
my_list = ['I', 'am', 'a', 'list']
" ".join(my_list)
# Out:
# 'I am a list'

# %%
import requests
import os
import json

# %%
# Define the base URL of the ranker endpoint
generator_endpoint = "https://tl3kpkfoc6yrvzbk.eu-west-1.aws.endpoints.huggingface.cloud"
ranker_endpoint = "https://yw45b0cpit1z2jzo.eu-west-1.aws.endpoints.huggingface.cloud"
sentiment_endpoint = "https://hzisbwxp65rx5k3c.eu-west-1.aws.endpoints.huggingface.cloud"

# %%
MY_API_TOKEN = "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"
headers = {"Authorization": "Bearer "+MY_API_TOKEN}
data = "I am a test"
response = requests.request("POST", generator_endpoint, headers=headers, data=data)

# %%
json.loads(response.content.decode("utf-8"))
# Out:
# {'error': 'Content type "None" not supported. Supported content types are: application/json, text/csv, text/plain, image/png, image/jpeg, image/jpg, image/tiff, image/bmp, image/gif, image/webp, image/x-image, audio/x-flac, audio/flac, audio/mpeg, audio/x-mpeg-3, audio/wave, audio/wav, audio/x-wav, audio/ogg, audio/x-audio, audio/webm, audio/webm;codecs=opus, audio/AMR, audio/amr, audio/AMR-WB, audio/AMR-WB+, audio/m4a, audio/x-m4a'}

# %%
import json
from typing import List
import requests as r
import base64
ENDPOINT_URL = "https://nsukoo29odbcm3ko.eu-west-1.aws.endpoints.huggingface.cloud"
HF_TOKEN = "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"


def predict(payload):
    payload = json.dumps(payload)
    response = r.request("POST",
        ENDPOINT_URL, headers={"Authorization": f"Bearer {HF_TOKEN}", "Contenttype":"application/json"}, data=payload
    )
    return response.json()
prediction = predict(
    payload={"inputs": "This is a test"}
)

# %%
prediction = predict(
    payload={"inputs": "This is a test"}
)

# %%
prediction
# Out:
# {'error': 'Content type "None" not supported. Supported content types are: application/json, text/csv, text/plain, image/png, image/jpeg, image/jpg, image/tiff, image/bmp, image/gif, image/webp, image/x-image, audio/x-flac, audio/flac, audio/mpeg, audio/x-mpeg-3, audio/wave, audio/wav, audio/x-wav, audio/ogg, audio/x-audio, audio/webm, audio/webm;codecs=opus, audio/AMR, audio/amr, audio/AMR-WB, audio/AMR-WB+, audio/m4a, audio/x-m4a'}

# %%
def predict(inputs: str = None):
    payload = {"inputs": inputs}  # wrap the input string in a dictionary with "inputs" key
    response = r.post(
        ENDPOINT_URL, headers={"Authorization": f"Bearer {HF_TOKEN}"}, json=payload
    )
    return response.json()

prediction = predict({"I am a test"})  # pass the input string as a value for "inputs" key
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/nizarsayad/Documents/VSCode/Jedha_Fullstack/Final-Project/testing.ipynb Cell 19 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/Users/nizarsayad/Documents/VSCode/Jedha_Fullstack/Final-Project/testing.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a>     response = r.post(
#       <a href='vscode-notebook-cell:/Users/nizarsayad/Documents/VSCode/Jedha_Fullstack/Final-Project/testing.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a>         ENDPOINT_URL, headers={"Authorization": f"Bearer {HF_TOKEN}"}, json=payload
#       <a href='vscode-notebook-cell:/Users/nizarsayad/Documents/VSCode/Jedha_Fullstack/Final-Project/testing.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a>     )
#       <a href='vscode-notebook-cell:/Users/nizarsayad/Documents/VSCode/Jedha_Fullstack/Final-Project/testing.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a>     return response.json()
# ...

# %%
prediction
# Out:
# {'error': 'text input must of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).'}

# %%
import requests
import json
import os

API_URL = ENDPOINT_URL
MY_API_TOKEN = "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"
headers = {"Authorization": f"Bearer {MY_API_TOKEN}", "Content-Type": "application/json"}  # Update content type to application/json

def predict(inputs: str = None):
    payload = {"inputs": inputs}  # wrap the input string in a dictionary with "inputs" key
    response = requests.post(API_URL, headers=headers, json=payload)  # Use json parameter to pass the payload as JSON data
    return response.json()

input_str = "I am a test"
prediction = predict(inputs=input_str)  # pass the input string as a value for "inputs" key

# %%
prediction
# Out:
# {'error': 'text input must of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).'}

# %%
import requests
import json
import os

API_URL = ENDPOINT_URL
MY_API_TOKEN = "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"
headers = {"Authorization": f"Bearer {MY_API_TOKEN}"}  # Update content type to application/json

def predict(inputs: str = None):
    payload = {
  "inputs": inputs,
  "moreData": 1,
  "customTask": True
} # wrap the input string in a list
    response = requests.post(API_URL, headers=headers, json=payload)  # Use json parameter to pass the payload as JSON data
    return response.json()

# %%
prediction = predict("Hello there")

# %%
prediction
# Out:
# {'error': 'text input must of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).'}

# %%
response = requests.post(API_URL, headers=headers, json={
  "inputs": {"inputs":"This is a sample input"},
  "moreData": 1,
  "customTask": True
})

# %%
response
# Out:
# <Response [400]>

# %%
response.text
# Out:
# '{"error":"text input must of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples)."}'

# %%
import json
import requests
API_URL = "https://nsukoo29odbcm3ko.eu-west-1.aws.endpoints.huggingface.cloud"
HF_TOKEN = "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"
headers = {"Authorization": f"Bearer {HF_TOKEN}"}
def query(payload):
    data = json.dumps(payload)
    response = requests.request("POST", API_URL, headers=headers, data=data)
    return json.loads(response.content.decode("utf-8"))
data = query({"inputs": "The answer to the universe is", "parameters":{"temperature": 1}, "options": {"use_cache": True, "wait_for_model": True, "max_tokens": 10, "top_p": 1, "top_k": 0}})

# %%
data
# Out:
# {'error': 'Content type "None" not supported. Supported content types are: application/json, text/csv, text/plain, image/png, image/jpeg, image/jpg, image/tiff, image/bmp, image/gif, image/webp, image/x-image, audio/x-flac, audio/flac, audio/mpeg, audio/x-mpeg-3, audio/wave, audio/wav, audio/x-wav, audio/ogg, audio/x-audio, audio/webm, audio/webm;codecs=opus, audio/AMR, audio/amr, audio/AMR-WB, audio/AMR-WB+, audio/m4a, audio/x-m4a'}

# %%
# Define the base URL of the ranker endpoint
generator_endpoint = "https://pxpr8qg4e4a6rmhx.eu-west-1.aws.endpoints.huggingface.cloud"
ranker_endpoint = "https://hjyq4wcnlte8swuz.eu-west-1.aws.endpoints.huggingface.cloud"
sentiment_endpoint = "https://r7hizww91fgofp2a.eu-west-1.aws.endpoints.huggingface.cloud"

# %%
headers = {"Authorization": f"Bearer {HF_TOKEN}", "Content-Type": "application/json"}
def query(payload):
    data = json.dumps(payload)
    response = requests.request("POST", generator_endpoint, headers=headers, data=data)
    return json.loads(response.content.decode("utf-8"))
data = query({"inputs": "It was a dark night.", "parameters": {"do_sample":True, "max_length": 50, "temperature": 0.7, "top_k": 50, "top_p": 0.95, "repetition_penalty": 1.2, "num_return_sequences": 4, "return_full_text": False}, "options":{"wait_for_model": True}})

# %%
data
# Out:
# [{'generated_text': ' I don’t remember exactly what time it was, but it must have been at least eight in the morning when we started our journey to meet up with Chris.'},
#  {'generated_text': ' I had been sleeping in a park bench, but my sleeping bag wasn’t there anymore and I couldn’t see out of it from where I was right now. The only light was the sun pe'},
#  {'generated_text': ' I couldn’t even see my hands and feet, as I didn’t want to look at them when I passed by the window. I walked past the front desk with my backpack still in it –'},
#  {'generated_text': ' I’d been in my office all day, and I had no idea what time it was…'}]

# %%
[datak["generated_text"] for datak in data]
# Out:
# [' I didn’t know why, but it seemed like something was wrong with me. I felt sick and nauseous from the pain of it all; even though it had been an hour since the last test,',
#  ' My girlfriend and I were sitting on the couch, watching a movie, when she said to me: “You’re gonna love this movie.”',
#  ' I had been awake for what felt like an hour, and still nothing happened.',
#  ' I had slept through the last of my class, but now felt like I would be falling asleep anytime I got to class. I looked at the clock on the wall and saw it was 8:15 am. I']

# %%
import json
import requests
headers = {"Authorization": f"Bearer {HF_TOKEN}", "Content-Type": "application/json"}
def query(payload):
    data = json.dumps(payload)
    response = requests.request("POST", ranker_endpoint, headers=headers, data=data)
    return json.loads(response.content.decode("utf-8"))
data = query(
    {
        "inputs": {
            "source_sentence": "That is a happy person",
            "sentences": ["That is a happy dog", "That is a very happy person", "Today is a sunny day"],
        }, "options":{"wait_for_model": True}
    }
)

# %%
data["similarities"]
# Out:
# [0.8812691569328308, 0.9769551753997803, 0.5754745602607727]

# %%
import json
import requests
headers = {"Authorization": f"Bearer {HF_TOKEN}", "Content-Type": "application/json"}
def query(payload):
    data = json.dumps(payload)
    response = requests.request("POST", "https://r7hizww91fgofp2a.eu-west-1.aws.endpoints.huggingface.cloud", headers=headers, data=data)
    return json.loads(response.content.decode("utf-8"))
data = query({"inputs": ["I like you.","I love you", "I hate you"], "options":{"wait_for_model": True}})

# %%
data
# Out:
# [{'label': 'positive', 'score': 0.803307294845581},
#  {'label': 'positive', 'score': 0.8594693541526794},
#  {'label': 'negative', 'score': 0.7866931557655334}]

# %%
new_scores = [1 - d['score'] if d['label'] == 'positive' else d['score'] for d in data]

# %%
new_scores
# Out:
# [0.19669270515441895, 0.14053064584732056, 0.7866931557655334]

# %%
import requests
import json

# Define the base URL of the endpoints
generator_endpoint = "http://0.0.0.0:8001"
ranker_endpoint = "http://0.0.0.0:8002"
sentiment_endpoint = "http://0.0.0.0:8003"

def generate(story_input):
    response = requests.post(f"{generator_endpoint}/generate", json={"story_input": story_input})
    return response.json()

def rank(story_input, continuations):
    response = requests.post(f"{ranker_endpoint}/rank_outputs", json={"story_input": story_input, "continuations": continuations})
    return response.json()

def guider(continuations):
    response = requests.post(f"{sentiment_endpoint}/analyze_sentiment", json={"continuations": continuations})
    return response.json()

def combine_predictions(story_input, sentiment_weight=0.2):
    generator_output = generate(story_input)
    gen_outputs_decoded = generator_output["gen_outputs_decoded"]
    gen_outputs_no_input_decoded = generator_output["gen_outputs_no_input_decoded"]
    ranker_output = rank(story_input, gen_outputs_no_input_decoded)
    ranks = ranker_output["rank_predictions"]
    guider_output = guider(gen_outputs_no_input_decoded)
    sentiment_scores = guider_output["sentiment_scores"]
    # Calculate the prior probability from the ranker score
    prior = ranks
    # Calculate the likelihood from the sentiment score
    likelihood = [sentiment_score**sentiment_weight for sentiment_score in sentiment_scores]
    # Calculate the posterior probability using Bayes' theorem
    posterior = [p * l for p, l in zip(prior, likelihood)]
    # Then in your story generation loop:
    continuation = gen_outputs_decoded[posterior.index(max(posterior))]
    return continuation

# %%
story_input = "Once upon a time."
combine_predictions(story_input)
# Out:
# 'Once upon a time.\nI was going to say the "once upon a time" thing but then I read it and it\'s just so... different.'

# %%
response.json()
# Out:
# {'gen_outputs_decoded': ['Once upon a time.',
#   "Once upon a time.\nIt's just that I'm a huge fan of the series and have played through it several times, and I've never been disappointed in the ending, it just felt like an afterthought and not one of the great ones.\nI'm glad you like it so much! I hope you don't have any problems with it being an afterthought because it is.",
#   'Once upon a time.\nI remember the time when it was the other way around.\nThe other way around?\nI remember the time when we were the ones who got a lot of attention when we got together.',
#   'Once upon a time.\n\n‘The Last of Us’ – a sequel to the first game – is out now on PlayStation 4 and Xbox One.\n\nThe game follows Ellie (played by Ellie Sotirio) as she travels to a new world to save humanity from the threat of a mysterious killer, but she’s quickly confronted with another threat – a giant, black beast with an agenda.',
# ...

# %%
gen_outputs_no_input_decoded = response.json()["gen_outputs_no_input_decoded"]

# %%
gen_outputs_no_input_decoded
# Out:
# ['\nI have been here since the start.\nI have been here for the last five years.',
#  '',
#  " I'm not sure why I still have it, though I can't remember why. I guess it just feels good to be out there again, and there is still hope.",
#  '\n\nThe day that the city of Atlanta, GA, became famous for its “garden city” (the nickname for the city’s famed “garden district”), there was a time when this area was known as Atlanta’s “garden capital.”\n\nThe city of Atlanta was known for its “garden city” (the nickname for the city’s famed “garden district”) for over',
#  " I was just like you. But I realized that it's not about being a dick, its about not being a dick and being honest about the things that matter in a relationship."]

# %%
response = rank(story_input, gen_outputs_no_input_decoded)

# %%
response
# Out:
# {'rank_predictions': [0.0013037901371717453,
#   0.0018538311123847961,
#   0.0578162856400013,
#   0.8285071849822998,
#   0.1105189174413681]}

# %%
response = guider(gen_outputs_no_input_decoded)

# %%
response
# Out:
# {'sentiment_scores': [0.012242140248417854,
#   0.22557516396045685,
#   0.08905887603759766,
#   0.006796262692660093,
#   0.25097131729125977]}
